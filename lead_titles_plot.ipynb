# %%
# 📊 Data Visualization Practice with Pandas and Matplotlib

# This notebook demonstrates:
# - How to load a CSV file using pandas
# - How to clean the data
# - How to plot a bar graph using matplotlib

# %%
import pandas as pd

# Load the leads_with_emails.csv file
df = pd.read_csv(r"C:\Users\Rishabh Giri\Downloads\leads_with_emails.csv")

# Preview the data
df.head()
# Out:
#                                                Title  \
# 0  Google AI - How we're making AI helpful for ev...
# 1                               Google AI - Research
# 2                               Google AI - Products
# 3  Google AI - Understanding AI: AI tools, traini...
# 4                     Google AI - Why we focus on AI
#
#                                  Link Email
# 0                  https://ai.google/   NaN
# 1          https://ai.google/research   NaN
# 2         https://ai.google/products/   NaN
# 3  https://ai.google/learn-ai-skills/   NaN
# 4           https://ai.google/why-ai/   NaN

# %%
print(df.columns)
# Out:
# Index(['Title', 'Link', 'Email'], dtype='object')

# %%
# Remove null values
df_cleaned = df.dropna()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
df = pd.read_csv(r"C:\Users\Rishabh Giri\Downloads\leads_with_emails.csv")

# Remove missing values and duplicates
df_cleaned = df.dropna().drop_duplicates()

# Count each unique Title (like article or lead category)
title_counts = df_cleaned['Title'].value_counts()

# Plot bar chart
plt.figure(figsize=(10,6))
title_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of Leads by Title')
plt.xlabel('Title')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
